# %%
# coding=utf-8
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

'''
huml and humw Length and Diameter of Humerus
ulnal and ulnaw Length and Diameter of Ulna
feml and femw Length and Diameter of Femur
tibl and tibw Length and Diameter of Tibiotarsus
tarl and tarw Length and Diameter of Tarsometatarsus

Исследовать основную взаимосвязь между размерами костей и
экологических групп и распознать экологические группы птиц по формам их костей
'''
pass

# %%
data = pd.read_csv('bird.csv')
data.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>huml</th>
#       <th>humw</th>
#       <th>ulnal</th>
#       <th>ulnaw</th>
#       <th>feml</th>
#       <th>femw</th>
#       <th>tibl</th>
#       <th>tibw</th>
#       <th>tarl</th>
#       <th>tarw</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>80.78</td>
#       <td>6.68</td>
#       <td>72.01</td>
#       <td>4.88</td>
#       <td>41.81</td>
#       <td>3.70</td>
#       <td>5.50</td>
#       <td>4.03</td>
#       <td>38.70</td>
#       <td>3.84</td>
#       <td>SW</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %%
'Возвращает размерность файла'
pass
data.shape
# Out:
# (420, 12)

# %%
'''
Описательная статистика: мат. ожидание, дисперсия, max, min
Исключает значение NaN
'''
pass
data.describe()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>huml</th>
#       <th>humw</th>
#       <th>ulnal</th>
#       <th>ulnaw</th>
#       <th>feml</th>
#       <th>femw</th>
#       <th>tibl</th>
#       <th>tibw</th>
#       <th>tarl</th>
#       <th>tarw</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>420.000000</td>
#       <td>419.000000</td>
#       <td>419.000000</td>
#       <td>417.000000</td>
#       <td>418.000000</td>
#       <td>418.000000</td>
#       <td>419.000000</td>
#       <td>418.000000</td>
#       <td>419.000000</td>
#       <td>419.000000</td>
#       <td>419.000000</td>
#     </tr>
#     <tr>
# ...

# %%
pd.plotting.scatter_matrix(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000026E104A8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000024742588>]], dtype=object)

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']

# %%
categorical_columns
# Out:
# ['type']

# %%
print(categorical_columns)
# Out:
# ['type']

# %%
numerical_columns = [c for c in data.columns if data[c].dtype.name != 'object']

# %%
print(numerical_columns)
# Out:
# ['id', 'huml', 'humw', 'ulnal', 'ulnaw', 'feml', 'femw', 'tibl', 'tibw', 'tarl', 'tarw']

# %%
data.median(axis=0)
# Out:
# id       209.500
# huml      44.180
# humw       3.500
# ulnal     43.710
# ulnaw      2.945
# feml      31.130
# femw       2.520
# tibl      52.120
# tibw       2.490
# tarl      31.740
# tarw       2.230
# dtype: float64
